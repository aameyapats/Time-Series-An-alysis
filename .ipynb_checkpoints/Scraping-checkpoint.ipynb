# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import urllib
from requests import get
from requests.exceptions import RequestException
from contextlib import closing

import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import lxml.html as lh

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMAResults
from sklearn.metrics import mean_squared_error as MSE

from  keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import keras.backend as K
from keras import layers
from keras.initializers import Zeros
from keras.callbacks import EarlyStopping
from keras.models import load_model
from keras.layers import LSTM
# Out:
# /Users/ameyapatankar/anaconda3/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)
# Using TensorFlow backend.

# %%
url='https://www.exchangerates.org.uk/GBP-USD-spot-exchange-rates-history-2019.html'#Create a handle, page, to handle the contents of the website

page = requests.get(url)#Store the contents of the website under doc

doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML

tr_elements = doc.xpath('//tr')

td_elements = doc.xpath('//td')

# %%
day = []

for t in tr_elements:
    if len(t) == 3:
        day.append(t.text_content())

# %%
day
# Out:
# ['Tuesday  1 January 2019£1 GBP = $1.2752British Pound US Dollar rate for 01/01/2019',
#  'Wednesday  2 January 2019£1 GBP = $1.2523British Pound US Dollar rate for 02/01/2019',
#  'Thursday  3 January 2019£1 GBP = $1.263British Pound US Dollar rate for 03/01/2019',
#  'Friday  4 January 2019£1 GBP = $1.2729British Pound US Dollar rate for 04/01/2019',
#  'Saturday  5 January 2019£1 GBP = $1.2723British Pound US Dollar rate for 05/01/2019',
#  'Sunday  6 January 2019£1 GBP = $1.2738British Pound US Dollar rate for 06/01/2019',
#  'Monday  7 January 2019£1 GBP = $1.2786British Pound US Dollar rate for 07/01/2019',
#  'Tuesday  8 January 2019£1 GBP = $1.2732British Pound US Dollar rate for 08/01/2019',
#  'Wednesday  9 January 2019£1 GBP = $1.2797British Pound US Dollar rate for 09/01/2019',
#  'Thursday 10 January 2019£1 GBP = $1.2753British Pound US Dollar rate for 10/01/2019',
#  'Friday 11 January 2019£1 GBP = $1.2845British Pound US Dollar rate for 11/01/2019',
#  'Saturday 12 January 2019£1 GBP = $1.2842British Pound US Dollar rate for 12/01/2019',
#  'Sunday 13 January 2019£1 GBP = $1.2852British Pound US Dollar rate for 13/01/2019',
#  'Monday 14 January 2019£1 GBP = $1.2874British Pound US Dollar rate for 14/01/2019',
#  'Tuesday 15 January 2019£1 GBP = $1.2873British Pound US Dollar rate for 15/01/2019',
#  'Wednesday 16 January 2019£1 GBP = $1.2886British Pound US Dollar rate for 16/01/2019',
#  'Thursday 17 January 2019£1 GBP = $1.2982British Pound US Dollar rate for 17/01/2019',
#  'Friday 18 January 2019£1 GBP = $1.2877British Pound US Dollar rate for 18/01/2019',
#  'Saturday 19 January 2019£1 GBP = $1.2877British Pound US Dollar rate for 19/01/2019',
#  'Sunday 20 January 2019£1 GBP = $1.2862British Pound US Dollar rate for 20/01/2019',
#  'Monday 21 January 2019£1 GBP = $1.2891British Pound US Dollar rate for 21/01/2019',
#  'Tuesday 22 January 2019£1 GBP = $1.2957British Pound US Dollar rate for 22/01/2019',
#  'Wednesday 23 January 2019£1 GBP = $1.3081British Pound US Dollar rate for 23/01/2019',
#  'Thursday 24 January 2019£1 GBP = $1.3125British Pound US Dollar rate for 24/01/2019',
#  'Friday 25 January 2019£1 GBP = $1.3195British Pound US Dollar rate for 25/01/2019',
#  'Saturday 26 January 2019£1 GBP = $1.3204British Pound US Dollar rate for 26/01/2019',
#  'Sunday 27 January 2019£1 GBP = $1.3207British Pound US Dollar rate for 27/01/2019',
#  'Monday 28 January 2019£1 GBP = $1.3157British Pound US Dollar rate for 28/01/2019',
#  'Tuesday 29 January 2019£1 GBP = $1.3078British Pound US Dollar rate for 29/01/2019',
#  'Wednesday 30 January 2019£1 GBP = $1.312British Pound US Dollar rate for 30/01/2019',
#  'Thursday 31 January 2019£1 GBP = $1.3106British Pound US Dollar rate for 31/01/2019',
#  'Friday  1 February 2019£1 GBP = $1.3085British Pound US Dollar rate for 01/02/2019',
#  'Saturday  2 February 2019£1 GBP = $1.3085British Pound US Dollar rate for 02/02/2019',
#  'Sunday  3 February 2019£1 GBP = $1.3078British Pound US Dollar rate for 03/02/2019',
#  'Monday  4 February 2019£1 GBP = $1.3035British Pound US Dollar rate for 04/02/2019',
#  'Tuesday  5 February 2019£1 GBP = $1.2956British Pound US Dollar rate for 05/02/2019',
#  'Wednesday  6 February 2019£1 GBP = $1.2936British Pound US Dollar rate for 06/02/2019',
#  'Thursday  7 February 2019£1 GBP = $1.295British Pound US Dollar rate for 07/02/2019',
#  'Friday  8 February 2019£1 GBP = $1.2941British Pound US Dollar rate for 08/02/2019',
#  'Saturday  9 February 2019£1 GBP = $1.2944British Pound US Dollar rate for 09/02/2019',
#  'Sunday 10 February 2019£1 GBP = $1.2937British Pound US Dollar rate for 10/02/2019',
#  'Monday 11 February 2019£1 GBP = $1.2862British Pound US Dollar rate for 11/02/2019',
#  'Tuesday 12 February 2019£1 GBP = $1.2895British Pound US Dollar rate for 12/02/2019',
#  'Wednesday 13 February 2019£1 GBP = $1.2853British Pound US Dollar rate for 13/02/2019',
#  'Thursday 14 February 2019£1 GBP = $1.2798British Pound US Dollar rate for 14/02/2019',
#  'Friday 15 February 2019£1 GBP = $1.2893British Pound US Dollar rate for 15/02/2019',
#  'Saturday 16 February 2019£1 GBP = $1.289British Pound US Dollar rate for 16/02/2019',
#  'Sunday 17 February 2019£1 GBP = $1.2905British Pound US Dollar rate for 17/02/2019',
#  'Monday 18 February 2019£1 GBP = $1.2923British Pound US Dollar rate for 18/02/2019',
#  'Tuesday 19 February 2019£1 GBP = $1.3058British Pound US Dollar rate for 19/02/2019',
#  'Wednesday 20 February 2019£1 GBP = $1.3046British Pound US Dollar rate for 20/02/2019',
#  'Thursday 21 February 2019£1 GBP = $1.3039British Pound US Dollar rate for 21/02/2019',
#  'Friday 22 February 2019£1 GBP = $1.3053British Pound US Dollar rate for 22/02/2019',
#  'Saturday 23 February 2019£1 GBP = $1.3053British Pound US Dollar rate for 23/02/2019',
#  'Sunday 24 February 2019£1 GBP = $1.3065British Pound US Dollar rate for 24/02/2019',
#  'Monday 25 February 2019£1 GBP = $1.3123British Pound US Dollar rate for 25/02/2019',
#  'Tuesday 26 February 2019£1 GBP = $1.3258British Pound US Dollar rate for 26/02/2019',
#  'Wednesday 27 February 2019£1 GBP = $1.3316British Pound US Dollar rate for 27/02/2019',
#  'Thursday 28 February 2019£1 GBP = $1.3263British Pound US Dollar rate for 28/02/2019',
#  'Friday  1 March 2019£1 GBP = $1.3211British Pound US Dollar rate for 01/03/2019',
#  'Saturday  2 March 2019£1 GBP = $1.3209British Pound US Dollar rate for 02/03/2019',
#  'Sunday  3 March 2019£1 GBP = $1.3238British Pound US Dollar rate for 03/03/2019',
#  'Monday  4 March 2019£1 GBP = $1.3178British Pound US Dollar rate for 04/03/2019',
#  'Tuesday  5 March 2019£1 GBP = $1.3157British Pound US Dollar rate for 05/03/2019',
#  'Wednesday  6 March 2019£1 GBP = $1.3181British Pound US Dollar rate for 06/03/2019',
#  'Thursday  7 March 2019£1 GBP = $1.3091British Pound US Dollar rate for 07/03/2019',
#  'Friday  8 March 2019£1 GBP = $1.3014British Pound US Dollar rate for 08/03/2019',
#  'Saturday  9 March 2019£1 GBP = $1.3017British Pound US Dollar rate for 09/03/2019',
#  'Sunday 10 March 2019£1 GBP = $1.2984British Pound US Dollar rate for 10/03/2019',
#  'Monday 11 March 2019£1 GBP = $1.324British Pound US Dollar rate for 11/03/2019',
#  'Tuesday 12 March 2019£1 GBP = $1.3064British Pound US Dollar rate for 12/03/2019',
#  'Wednesday 13 March 2019£1 GBP = $1.3283British Pound US Dollar rate for 13/03/2019',
#  'Thursday 14 March 2019£1 GBP = $1.3257British Pound US Dollar rate for 14/03/2019',
#  'Friday 15 March 2019£1 GBP = $1.3309British Pound US Dollar rate for 15/03/2019',
#  'Saturday 16 March 2019£1 GBP = $1.3309British Pound US Dollar rate for 16/03/2019',
#  'Sunday 17 March 2019£1 GBP = $1.3298British Pound US Dollar rate for 17/03/2019',
#  'Monday 18 March 2019£1 GBP = $1.3258British Pound US Dollar rate for 18/03/2019',
#  'Tuesday 19 March 2019£1 GBP = $1.3267British Pound US Dollar rate for 19/03/2019',
#  'Wednesday 20 March 2019£1 GBP = $1.3203British Pound US Dollar rate for 20/03/2019',
#  'Thursday 21 March 2019£1 GBP = $1.3133British Pound US Dollar rate for 21/03/2019',
#  'Friday 22 March 2019£1 GBP = $1.3214British Pound US Dollar rate for 22/03/2019',
#  'Saturday 23 March 2019£1 GBP = $1.3211British Pound US Dollar rate for 23/03/2019',
#  'Sunday 24 March 2019£1 GBP = $1.3211British Pound US Dollar rate for 24/03/2019',
#  'Monday 25 March 2019£1 GBP = $1.3209British Pound US Dollar rate for 25/03/2019',
#  'Tuesday 26 March 2019£1 GBP = $1.3212British Pound US Dollar rate for 26/03/2019',
#  'Wednesday 27 March 2019£1 GBP = $1.3148British Pound US Dollar rate for 27/03/2019',
#  'Thursday 28 March 2019£1 GBP = $1.3051British Pound US Dollar rate for 28/03/2019',
#  'Friday 29 March 2019£1 GBP = $1.3043British Pound US Dollar rate for 29/03/2019',
#  'Saturday 30 March 2019£1 GBP = $1.3044British Pound US Dollar rate for 30/03/2019',
#  'Sunday 31 March 2019£1 GBP = $1.3023British Pound US Dollar rate for 31/03/2019',
#  'Monday  1 April 2019£1 GBP = $1.3077British Pound US Dollar rate for 01/04/2019',
#  'Tuesday  2 April 2019£1 GBP = $1.3133British Pound US Dollar rate for 02/04/2019',
#  'Wednesday  3 April 2019£1 GBP = $1.3175British Pound US Dollar rate for 03/04/2019',
#  'Thursday  4 April 2019£1 GBP = $1.3075British Pound US Dollar rate for 04/04/2019',
#  'Friday  5 April 2019£1 GBP = $1.3037British Pound US Dollar rate for 05/04/2019',
#  'Saturday  6 April 2019£1 GBP = $1.3037British Pound US Dollar rate for 06/04/2019',
#  'Sunday  7 April 2019£1 GBP = $1.3035British Pound US Dollar rate for 07/04/2019',
#  'Monday  8 April 2019£1 GBP = $1.3061British Pound US Dollar rate for 08/04/2019',
#  'Tuesday  9 April 2019£1 GBP = $1.3058British Pound US Dollar rate for 09/04/2019',
#  'Wednesday 10 April 2019£1 GBP = $1.3091British Pound US Dollar rate for 10/04/2019',
#  'Thursday 11 April 2019£1 GBP = $1.3057British Pound US Dollar rate for 11/04/2019',
#  'Friday 12 April 2019£1 GBP = $1.3077British Pound US Dollar rate for 12/04/2019',
#  'Saturday 13 April 2019£1 GBP = $1.3077British Pound US Dollar rate for 13/04/2019',
#  'Sunday 14 April 2019£1 GBP = $1.3078British Pound US Dollar rate for 14/04/2019',
#  'Monday 15 April 2019£1 GBP = $1.3097British Pound US Dollar rate for 15/04/2019',
#  'Tuesday 16 April 2019£1 GBP = $1.3042British Pound US Dollar rate for 16/04/2019',
#  'Wednesday 17 April 2019£1 GBP = $1.3037British Pound US Dollar rate for 17/04/2019',
#  'Thursday 18 April 2019£1 GBP = $1.2989British Pound US Dollar rate for 18/04/2019',
#  'Friday 19 April 2019£1 GBP = $1.2996British Pound US Dollar rate for 19/04/2019',
#  'Saturday 20 April 2019£1 GBP = $1.2996British Pound US Dollar rate for 20/04/2019',
#  'Sunday 21 April 2019£1 GBP = $1.2995British Pound US Dollar rate for 21/04/2019',
#  'Monday 22 April 2019£1 GBP = $1.2982British Pound US Dollar rate for 22/04/2019',
#  'Tuesday 23 April 2019£1 GBP = $1.2935British Pound US Dollar rate for 23/04/2019',
#  'Wednesday 24 April 2019£1 GBP = $1.2907British Pound US Dollar rate for 24/04/2019',
#  'Thursday 25 April 2019£1 GBP = $1.29British Pound US Dollar rate for 25/04/2019',
#  'Friday 26 April 2019£1 GBP = $1.2919British Pound US Dollar rate for 26/04/2019',
#  'Saturday 27 April 2019£1 GBP = $1.2917British Pound US Dollar rate for 27/04/2019',
#  'Sunday 28 April 2019£1 GBP = $1.292British Pound US Dollar rate for 28/04/2019',
#  'Monday 29 April 2019£1 GBP = $1.2931British Pound US Dollar rate for 29/04/2019',
#  'Tuesday 30 April 2019£1 GBP = $1.3032British Pound US Dollar rate for 30/04/2019',
#  'Wednesday  1 May 2019£1 GBP = $1.3057British Pound US Dollar rate for 01/05/2019',
#  'Thursday  2 May 2019£1 GBP = $1.3033British Pound US Dollar rate for 02/05/2019',
#  'Friday  3 May 2019£1 GBP = $1.3173British Pound US Dollar rate for 03/05/2019',
#  'Saturday  4 May 2019£1 GBP = $1.3173British Pound US Dollar rate for 04/05/2019',
#  'Sunday  5 May 2019£1 GBP = $1.3169British Pound US Dollar rate for 05/05/2019',
#  'Monday  6 May 2019£1 GBP = $1.3091British Pound US Dollar rate for 06/05/2019',
#  'Tuesday  7 May 2019£1 GBP = $1.3071British Pound US Dollar rate for 07/05/2019',
#  'Wednesday  8 May 2019£1 GBP = $1.3012British Pound US Dollar rate for 08/05/2019',
#  'Thursday  9 May 2019£1 GBP = $1.3011British Pound US Dollar rate for 09/05/2019',
#  'Friday 10 May 2019£1 GBP = $1.2999British Pound US Dollar rate for 10/05/2019',
#  'Saturday 11 May 2019£1 GBP = $1.2999British Pound US Dollar rate for 11/05/2019',
#  'Sunday 12 May 2019£1 GBP = $1.3007British Pound US Dollar rate for 12/05/2019',
#  'Monday 13 May 2019£1 GBP = $1.295British Pound US Dollar rate for 13/05/2019',
#  'Tuesday 14 May 2019£1 GBP = $1.291British Pound US Dollar rate for 14/05/2019',
#  'Wednesday 15 May 2019£1 GBP = $1.2845British Pound US Dollar rate for 15/05/2019',
#  'Thursday 16 May 2019£1 GBP = $1.2796British Pound US Dollar rate for 16/05/2019',
#  'Friday 17 May 2019£1 GBP = $1.2719British Pound US Dollar rate for 17/05/2019',
#  'Saturday 18 May 2019£1 GBP = $1.2719British Pound US Dollar rate for 18/05/2019',
#  'Sunday 19 May 2019£1 GBP = $1.2728British Pound US Dollar rate for 19/05/2019',
#  'Monday 20 May 2019£1 GBP = $1.2728British Pound US Dollar rate for 20/05/2019',
#  'Tuesday 21 May 2019£1 GBP = $1.2705British Pound US Dollar rate for 21/05/2019',
#  'Wednesday 22 May 2019£1 GBP = $1.2665British Pound US Dollar rate for 22/05/2019',
#  'Thursday 23 May 2019£1 GBP = $1.2662British Pound US Dollar rate for 23/05/2019',
#  'Friday 24 May 2019£1 GBP = $1.2714British Pound US Dollar rate for 24/05/2019',
#  'Saturday 25 May 2019£1 GBP = $1.2713British Pound US Dollar rate for 25/05/2019',
#  'Sunday 26 May 2019£1 GBP = $1.2728British Pound US Dollar rate for 26/05/2019',
#  'Monday 27 May 2019£1 GBP = $1.2682British Pound US Dollar rate for 27/05/2019',
#  'Tuesday 28 May 2019£1 GBP = $1.2657British Pound US Dollar rate for 28/05/2019',
#  'Wednesday 29 May 2019£1 GBP = $1.2629British Pound US Dollar rate for 29/05/2019',
#  'Thursday 30 May 2019£1 GBP = $1.261British Pound US Dollar rate for 30/05/2019',
#  'Friday 31 May 2019£1 GBP = $1.2639British Pound US Dollar rate for 31/05/2019',
#  'Saturday  1 June 2019£1 GBP = $1.2639British Pound US Dollar rate for 01/06/2019',
#  'Sunday  2 June 2019£1 GBP = $1.2637British Pound US Dollar rate for 02/06/2019',
#  'Monday  3 June 2019£1 GBP = $1.2667British Pound US Dollar rate for 03/06/2019',
#  'Tuesday  4 June 2019£1 GBP = $1.2699British Pound US Dollar rate for 04/06/2019',
#  'Wednesday  5 June 2019£1 GBP = $1.269British Pound US Dollar rate for 05/06/2019',
#  'Thursday  6 June 2019£1 GBP = $1.2697British Pound US Dollar rate for 06/06/2019',
#  'Friday  7 June 2019£1 GBP = $1.2737British Pound US Dollar rate for 07/06/2019',
#  'Saturday  8 June 2019£1 GBP = $1.2737British Pound US Dollar rate for 08/06/2019',
#  'Sunday  9 June 2019£1 GBP = $1.2723British Pound US Dollar rate for 09/06/2019',
#  'Monday 10 June 2019£1 GBP = $1.2688British Pound US Dollar rate for 10/06/2019',
#  'Tuesday 11 June 2019£1 GBP = $1.2723British Pound US Dollar rate for 11/06/2019',
#  'Wednesday 12 June 2019£1 GBP = $1.2691British Pound US Dollar rate for 12/06/2019',
#  'Thursday 13 June 2019£1 GBP = $1.268British Pound US Dollar rate for 13/06/2019',
#  'Friday 14 June 2019£1 GBP = $1.2591British Pound US Dollar rate for 14/06/2019',
#  'Saturday 15 June 2019£1 GBP = $1.2589British Pound US Dollar rate for 15/06/2019',
#  'Sunday 16 June 2019£1 GBP = $1.2591British Pound US Dollar rate for 16/06/2019',
#  'Monday 17 June 2019£1 GBP = $1.2537British Pound US Dollar rate for 17/06/2019',
#  'Tuesday 18 June 2019£1 GBP = $1.2557British Pound US Dollar rate for 18/06/2019',
#  'Wednesday 19 June 2019£1 GBP = $1.2651British Pound US Dollar rate for 19/06/2019',
#  'Thursday 20 June 2019£1 GBP = $1.2705British Pound US Dollar rate for 20/06/2019',
#  'Friday 21 June 2019£1 GBP = $1.2742British Pound US Dollar rate for 21/06/2019',
#  'Saturday 22 June 2019£1 GBP = $1.2742British Pound US Dollar rate for 22/06/2019',
#  'Sunday 23 June 2019£1 GBP = $1.2743British Pound US Dollar rate for 23/06/2019',
#  'Monday 24 June 2019£1 GBP = $1.2738British Pound US Dollar rate for 24/06/2019',
#  'Tuesday 25 June 2019£1 GBP = $1.2686British Pound US Dollar rate for 25/06/2019',
#  'Wednesday 26 June 2019£1 GBP = $1.2693British Pound US Dollar rate for 26/06/2019',
#  'Thursday 27 June 2019£1 GBP = $1.267British Pound US Dollar rate for 27/06/2019',
#  'Friday 28 June 2019£1 GBP = $1.2695British Pound US Dollar rate for 28/06/2019',
#  'Saturday 29 June 2019£1 GBP = $1.2695British Pound US Dollar rate for 29/06/2019',
#  'Sunday 30 June 2019£1 GBP = $1.2697British Pound US Dollar rate for 30/06/2019',
#  'Monday  1 July 2019£1 GBP = $1.2645British Pound US Dollar rate for 01/07/2019',
#  'Tuesday  2 July 2019£1 GBP = $1.2597British Pound US Dollar rate for 02/07/2019',
#  'Wednesday  3 July 2019£1 GBP = $1.2579British Pound US Dollar rate for 03/07/2019',
#  'Thursday  4 July 2019£1 GBP = $1.2582British Pound US Dollar rate for 04/07/2019',
#  'Friday  5 July 2019£1 GBP = $1.2521British Pound US Dollar rate for 05/07/2019',
#  'Saturday  6 July 2019£1 GBP = $1.2522British Pound US Dollar rate for 06/07/2019',
#  'Sunday  7 July 2019£1 GBP = $1.2526British Pound US Dollar rate for 07/07/2019',
#  'Monday  8 July 2019£1 GBP = $1.2518British Pound US Dollar rate for 08/07/2019',
#  'Tuesday  9 July 2019£1 GBP = $1.2459British Pound US Dollar rate for 09/07/2019',
#  'Wednesday 10 July 2019£1 GBP = $1.2509British Pound US Dollar rate for 10/07/2019',
#  'Thursday 11 July 2019£1 GBP = $1.253British Pound US Dollar rate for 11/07/2019',
#  'Friday 12 July 2019£1 GBP = $1.2572British Pound US Dollar rate for 12/07/2019',
#  'Saturday 13 July 2019£1 GBP = $1.2572British Pound US Dollar rate for 13/07/2019',
#  'Sunday 14 July 2019£1 GBP = $1.2576British Pound US Dollar rate for 14/07/2019',
#  'Monday 15 July 2019£1 GBP = $1.2519British Pound US Dollar rate for 15/07/2019',
#  'Tuesday 16 July 2019£1 GBP = $1.2409British Pound US Dollar rate for 16/07/2019',
#  'Wednesday 17 July 2019£1 GBP = $1.2433British Pound US Dollar rate for 17/07/2019',
#  'Thursday 18 July 2019£1 GBP = $1.2531British Pound US Dollar rate for 18/07/2019',
#  'Friday 19 July 2019£1 GBP = $1.2502British Pound US Dollar rate for 19/07/2019',
#  'Saturday 20 July 2019£1 GBP = $1.2502British Pound US Dollar rate for 20/07/2019',
#  'Sunday 21 July 2019£1 GBP = $1.2506British Pound US Dollar rate for 21/07/2019',
#  'Monday 22 July 2019£1 GBP = $1.2478British Pound US Dollar rate for 22/07/2019',
#  'Tuesday 23 July 2019£1 GBP = $1.2438British Pound US Dollar rate for 23/07/2019',
#  'Wednesday 24 July 2019£1 GBP = $1.2482British Pound US Dollar rate for 24/07/2019',
#  'Thursday 25 July 2019£1 GBP = $1.2453British Pound US Dollar rate for 25/07/2019',
#  'Friday 26 July 2019£1 GBP = $1.2383British Pound US Dollar rate for 26/07/2019',
#  'Saturday 27 July 2019£1 GBP = $1.2383British Pound US Dollar rate for 27/07/2019',
#  'Sunday 28 July 2019£1 GBP = $1.238British Pound US Dollar rate for 28/07/2019',
#  'Monday 29 July 2019£1 GBP = $1.2222British Pound US Dollar rate for 29/07/2019',
#  'Tuesday 30 July 2019£1 GBP = $1.2158British Pound US Dollar rate for 30/07/2019',
#  'Wednesday 31 July 2019£1 GBP = $1.2161British Pound US Dollar rate for 31/07/2019',
#  'Thursday  1 August 2019£1 GBP = $1.2122British Pound US Dollar rate for 01/08/2019',
#  'Friday  2 August 2019£1 GBP = $1.2161British Pound US Dollar rate for 02/08/2019',
#  'Saturday  3 August 2019£1 GBP = $1.2161British Pound US Dollar rate for 03/08/2019',
#  'Sunday  4 August 2019£1 GBP = $1.2148British Pound US Dollar rate for 04/08/2019',
#  'Monday  5 August 2019£1 GBP = $1.2153British Pound US Dollar rate for 05/08/2019',
#  'Tuesday  6 August 2019£1 GBP = $1.2166British Pound US Dollar rate for 06/08/2019',
#  'Wednesday  7 August 2019£1 GBP = $1.2145British Pound US Dollar rate for 07/08/2019',
#  'Thursday  8 August 2019£1 GBP = $1.214British Pound US Dollar rate for 08/08/2019',
#  'Friday  9 August 2019£1 GBP = $1.2038British Pound US Dollar rate for 09/08/2019',
#  'Saturday 10 August 2019£1 GBP = $1.2038British Pound US Dollar rate for 10/08/2019',
#  'Sunday 11 August 2019£1 GBP = $1.2033British Pound US Dollar rate for 11/08/2019',
#  'Monday 12 August 2019£1 GBP = $1.2078British Pound US Dollar rate for 12/08/2019',
#  'Tuesday 13 August 2019£1 GBP = $1.2057British Pound US Dollar rate for 13/08/2019',
#  'Wednesday 14 August 2019£1 GBP = $1.206British Pound US Dollar rate for 14/08/2019',
#  'Thursday 15 August 2019£1 GBP = $1.209British Pound US Dollar rate for 15/08/2019',
#  'Friday 16 August 2019£1 GBP = $1.215British Pound US Dollar rate for 16/08/2019',
#  'Saturday 17 August 2019£1 GBP = $1.215British Pound US Dollar rate for 17/08/2019',
#  'Sunday 18 August 2019£1 GBP = $1.2158British Pound US Dollar rate for 18/08/2019',
#  'Monday 19 August 2019£1 GBP = $1.2127British Pound US Dollar rate for 19/08/2019',
#  'Tuesday 20 August 2019£1 GBP = $1.2166British Pound US Dollar rate for 20/08/2019',
#  'Wednesday 21 August 2019£1 GBP = $1.213British Pound US Dollar rate for 21/08/2019',
#  'Thursday 22 August 2019£1 GBP = $1.2252British Pound US Dollar rate for 22/08/2019',
#  'Friday 23 August 2019£1 GBP = $1.2278British Pound US Dollar rate for 23/08/2019',
#  'Saturday 24 August 2019£1 GBP = $1.2277British Pound US Dollar rate for 24/08/2019',
#  'Sunday 25 August 2019£1 GBP = $1.227British Pound US Dollar rate for 25/08/2019',
#  'Monday 26 August 2019£1 GBP = $1.222British Pound US Dollar rate for 26/08/2019',
#  'Tuesday 27 August 2019£1 GBP = $1.2285British Pound US Dollar rate for 27/08/2019',
#  'Wednesday 28 August 2019£1 GBP = $1.2218British Pound US Dollar rate for 28/08/2019',
#  'Thursday 29 August 2019£1 GBP = $1.2183British Pound US Dollar rate for 29/08/2019',
#  'Friday 30 August 2019£1 GBP = $1.2159British Pound US Dollar rate for 30/08/2019',
#  'Saturday 31 August 2019£1 GBP = $1.2159British Pound US Dollar rate for 31/08/2019',
#  'Sunday  1 September 2019£1 GBP = $1.216British Pound US Dollar rate for 01/09/2019',
#  'Monday  2 September 2019£1 GBP = $1.2064British Pound US Dollar rate for 02/09/2019',
#  'Tuesday  3 September 2019£1 GBP = $1.2087British Pound US Dollar rate for 03/09/2019',
#  'Wednesday  4 September 2019£1 GBP = $1.2248British Pound US Dollar rate for 04/09/2019',
#  'Thursday  5 September 2019£1 GBP = $1.2328British Pound US Dollar rate for 05/09/2019',
#  'Friday  6 September 2019£1 GBP = $1.2284British Pound US Dollar rate for 06/09/2019',
#  'Saturday  7 September 2019£1 GBP = $1.2285British Pound US Dollar rate for 07/09/2019',
#  'Sunday  8 September 2019£1 GBP = $1.2284British Pound US Dollar rate for 08/09/2019',
#  'Monday  9 September 2019£1 GBP = $1.2348British Pound US Dollar rate for 09/09/2019',
#  'Tuesday 10 September 2019£1 GBP = $1.2356British Pound US Dollar rate for 10/09/2019',
#  'Wednesday 11 September 2019£1 GBP = $1.2327British Pound US Dollar rate for 11/09/2019',
#  'Thursday 12 September 2019£1 GBP = $1.2334British Pound US Dollar rate for 12/09/2019',
#  'Friday 13 September 2019£1 GBP = $1.2505British Pound US Dollar rate for 13/09/2019',
#  'Saturday 14 September 2019£1 GBP = $1.2506British Pound US Dollar rate for 14/09/2019',
#  'Sunday 15 September 2019£1 GBP = $1.2493British Pound US Dollar rate for 15/09/2019',
#  'Monday 16 September 2019£1 GBP = $1.2429British Pound US Dollar rate for 16/09/2019',
#  'Tuesday 17 September 2019£1 GBP = $1.2503British Pound US Dollar rate for 17/09/2019',
#  'Wednesday 18 September 2019£1 GBP = $1.2475British Pound US Dollar rate for 18/09/2019',
#  'Thursday 19 September 2019£1 GBP = $1.2522British Pound US Dollar rate for 19/09/2019',
#  'Friday 20 September 2019£1 GBP = $1.2472British Pound US Dollar rate for 20/09/2019',
#  'Saturday 21 September 2019£1 GBP = $1.2472British Pound US Dollar rate for 21/09/2019',
#  'Sunday 22 September 2019£1 GBP = $1.2472British Pound US Dollar rate for 22/09/2019',
#  'Monday 23 September 2019£1 GBP = $1.2437British Pound US Dollar rate for 23/09/2019',
#  'Tuesday 24 September 2019£1 GBP = $1.2494British Pound US Dollar rate for 24/09/2019',
#  'Wednesday 25 September 2019£1 GBP = $1.2357British Pound US Dollar rate for 25/09/2019',
#  'Thursday 26 September 2019£1 GBP = $1.2326British Pound US Dollar rate for 26/09/2019',
#  'Friday 27 September 2019£1 GBP = $1.229British Pound US Dollar rate for 27/09/2019',
#  'Saturday 28 September 2019£1 GBP = $1.229British Pound US Dollar rate for 28/09/2019',
#  'Sunday 29 September 2019£1 GBP = $1.2295British Pound US Dollar rate for 29/09/2019',
#  'Monday 30 September 2019£1 GBP = $1.2289British Pound US Dollar rate for 30/09/2019',
#  'Tuesday  1 October 2019£1 GBP = $1.2288British Pound US Dollar rate for 01/10/2019',
#  'Wednesday  2 October 2019£1 GBP = $1.2299British Pound US Dollar rate for 02/10/2019',
#  'Thursday  3 October 2019£1 GBP = $1.2336British Pound US Dollar rate for 03/10/2019',
#  'Friday  4 October 2019£1 GBP = $1.2333British Pound US Dollar rate for 04/10/2019',
#  'Saturday  5 October 2019£1 GBP = $1.2335British Pound US Dollar rate for 05/10/2019',
#  'Sunday  6 October 2019£1 GBP = $1.2331British Pound US Dollar rate for 06/10/2019',
#  'Monday  7 October 2019£1 GBP = $1.2287British Pound US Dollar rate for 07/10/2019',
#  'Tuesday  8 October 2019£1 GBP = $1.2225British Pound US Dollar rate for 08/10/2019',
#  'Wednesday  9 October 2019£1 GBP = $1.2213British Pound US Dollar rate for 09/10/2019',
#  'Thursday 10 October 2019£1 GBP = $1.2435British Pound US Dollar rate for 10/10/2019',
#  'Friday 11 October 2019£1 GBP = $1.2645British Pound US Dollar rate for 11/10/2019',
#  'Saturday 12 October 2019£1 GBP = $1.2645British Pound US Dollar rate for 12/10/2019',
#  'Sunday 13 October 2019£1 GBP = $1.2637British Pound US Dollar rate for 13/10/2019',
#  'Monday 14 October 2019£1 GBP = $1.2605British Pound US Dollar rate for 14/10/2019',
#  'Tuesday 15 October 2019£1 GBP = $1.2767British Pound US Dollar rate for 15/10/2019',
#  'Wednesday 16 October 2019£1 GBP = $1.2817British Pound US Dollar rate for 16/10/2019',
#  'Thursday 17 October 2019£1 GBP = $1.2877British Pound US Dollar rate for 17/10/2019',
#  'Friday 18 October 2019£1 GBP = $1.2981British Pound US Dollar rate for 18/10/2019',
#  'Saturday 19 October 2019£1 GBP = $1.2981British Pound US Dollar rate for 19/10/2019',
#  'Sunday 20 October 2019£1 GBP = $1.2901British Pound US Dollar rate for 20/10/2019',
#  'Monday 21 October 2019£1 GBP = $1.2966British Pound US Dollar rate for 21/10/2019',
#  'Tuesday 22 October 2019£1 GBP = $1.2889British Pound US Dollar rate for 22/10/2019',
#  'Wednesday 23 October 2019£1 GBP = $1.2915British Pound US Dollar rate for 23/10/2019',
#  'Thursday 24 October 2019£1 GBP = $1.2843British Pound US Dollar rate for 24/10/2019',
#  'Friday 25 October 2019£1 GBP = $1.2824British Pound US Dollar rate for 25/10/2019',
#  'Saturday 26 October 2019£1 GBP = $1.2827British Pound US Dollar rate for 26/10/2019',
#  'Sunday 27 October 2019£1 GBP = $1.2827British Pound US Dollar rate for 27/10/2019',
#  'Monday 28 October 2019£1 GBP = $1.2856British Pound US Dollar rate for 28/10/2019',
#  'Tuesday 29 October 2019£1 GBP = $1.2867British Pound US Dollar rate for 29/10/2019',
#  'Wednesday 30 October 2019£1 GBP = $1.29British Pound US Dollar rate for 30/10/2019',
#  'Thursday 31 October 2019£1 GBP = $1.2936British Pound US Dollar rate for 31/10/2019',
#  'Friday  1 November 2019£1 GBP = $1.2942British Pound US Dollar rate for 01/11/2019',
#  'Saturday  2 November 2019£1 GBP = $1.2942British Pound US Dollar rate for 02/11/2019',
#  'Sunday  3 November 2019£1 GBP = $1.2937British Pound US Dollar rate for 03/11/2019',
#  'Monday  4 November 2019£1 GBP = $1.2887British Pound US Dollar rate for 04/11/2019',
#  'Tuesday  5 November 2019£1 GBP = $1.2882British Pound US Dollar rate for 05/11/2019',
#  'Wednesday  6 November 2019£1 GBP = $1.2854British Pound US Dollar rate for 06/11/2019',
#  'Thursday  7 November 2019£1 GBP = $1.2821British Pound US Dollar rate for 07/11/2019',
#  'Friday  8 November 2019£1 GBP = $1.2775British Pound US Dollar rate for 08/11/2019',
#  'Saturday  9 November 2019£1 GBP = $1.2775British Pound US Dollar rate for 09/11/2019',
#  'Sunday 10 November 2019£1 GBP = $1.2795British Pound US Dollar rate for 10/11/2019',
#  'Monday 11 November 2019£1 GBP = $1.2855British Pound US Dollar rate for 11/11/2019',
#  'Tuesday 12 November 2019£1 GBP = $1.2854British Pound US Dollar rate for 12/11/2019',
#  'Wednesday 13 November 2019£1 GBP = $1.2853British Pound US Dollar rate for 13/11/2019',
#  'Thursday 14 November 2019£1 GBP = $1.2882British Pound US Dollar rate for 14/11/2019',
#  'Friday 15 November 2019£1 GBP = $1.2904British Pound US Dollar rate for 15/11/2019',
#  'Saturday 16 November 2019£1 GBP = $1.2904British Pound US Dollar rate for 16/11/2019',
#  'Sunday 17 November 2019£1 GBP = $1.2921British Pound US Dollar rate for 17/11/2019',
#  'Monday 18 November 2019£1 GBP = $1.2949British Pound US Dollar rate for 18/11/2019',
#  'Tuesday 19 November 2019£1 GBP = $1.293British Pound US Dollar rate for 19/11/2019',
#  'Wednesday 20 November 2019£1 GBP = $1.2926British Pound US Dollar rate for 20/11/2019',
#  'Thursday 21 November 2019£1 GBP = $1.2918British Pound US Dollar rate for 21/11/2019',
#  'Friday 22 November 2019£1 GBP = $1.2835British Pound US Dollar rate for 22/11/2019',
#  'Saturday 23 November 2019£1 GBP = $1.2835British Pound US Dollar rate for 23/11/2019',
#  'Sunday 24 November 2019£1 GBP = $1.2848British Pound US Dollar rate for 24/11/2019',
#  'Monday 25 November 2019£1 GBP = $1.2898British Pound US Dollar rate for 25/11/2019',
#  'Tuesday 26 November 2019£1 GBP = $1.2863British Pound US Dollar rate for 26/11/2019',
#  'Wednesday 27 November 2019£1 GBP = $1.2934British Pound US Dollar rate for 27/11/2019',
#  'Thursday 28 November 2019£1 GBP = $1.291British Pound US Dollar rate for 28/11/2019',
#  'Friday 29 November 2019£1 GBP = $1.2928British Pound US Dollar rate for 29/11/2019',
#  'Saturday 30 November 2019£1 GBP = $1.2928British Pound US Dollar rate for 30/11/2019',
#  'Sunday  1 December 2019£1 GBP = $1.2911British Pound US Dollar rate for 01/12/2019',
#  'Monday  2 December 2019£1 GBP = $1.2939British Pound US Dollar rate for 02/12/2019',
#  'Tuesday  3 December 2019£1 GBP = $1.3British Pound US Dollar rate for 03/12/2019',
#  'Wednesday  4 December 2019£1 GBP = $1.311British Pound US Dollar rate for 04/12/2019',
#  'Thursday  5 December 2019£1 GBP = $1.316British Pound US Dollar rate for 05/12/2019',
#  'Friday  6 December 2019£1 GBP = $1.3136British Pound US Dollar rate for 06/12/2019',
#  'Saturday  7 December 2019£1 GBP = $1.3136British Pound US Dollar rate for 07/12/2019',
#  'Sunday  8 December 2019£1 GBP = $1.314British Pound US Dollar rate for 08/12/2019',
#  'Monday  9 December 2019£1 GBP = $1.3145British Pound US Dollar rate for 09/12/2019',
#  'Tuesday 10 December 2019£1 GBP = $1.3131British Pound US Dollar rate for 10/12/2019',
#  'Wednesday 11 December 2019£1 GBP = $1.3198British Pound US Dollar rate for 11/12/2019',
#  'Thursday 12 December 2019£1 GBP = $1.347British Pound US Dollar rate for 12/12/2019',
#  'Friday 13 December 2019£1 GBP = $1.3332British Pound US Dollar rate for 13/12/2019',
#  'Saturday 14 December 2019£1 GBP = $1.3332British Pound US Dollar rate for 14/12/2019',
#  'Sunday 15 December 2019£1 GBP = $1.3353British Pound US Dollar rate for 15/12/2019',
#  'Monday 16 December 2019£1 GBP = $1.3255British Pound US Dollar rate for 16/12/2019']

# %%
tmp = pd.DataFrame(day)
tmp.columns = ['Data']

# %%
tmp['Date'] = tmp['Data'].apply(lambda x : x.split("ay")[-1].split("£1")[0])
# filter((lambda x: re.search(r'L', x)),s)
tmp['Date'] = pd.to_datetime(tmp['Date'])
tmp['Rate'] = tmp['Data'].apply(lambda x : x.split("$")[-1].split("British")[0])
tmp.drop(['Data'],axis = 1,inplace= True)
# tmp.index = tmp['Date']
tmp['Rate'] = tmp.index

# %%
tmp.index
# Out:
# RangeIndex(start=0, stop=350, step=1)

# %%
tmp.head(n=40)
# Out:
#          Date  Rate
# 0  2019-01-01     0
# 1  2019-01-02     1
# 2  2019-01-03     2
# 3  2019-01-04     3
# 4  2019-01-05     4
# 5  2019-01-06     5
# 6  2019-01-07     6
# 7  2019-01-08     7
# 8  2019-01-09     8
# 9  2019-01-10     9
# 10 2019-01-11    10
# 11 2019-01-12    11
# 12 2019-01-13    12
# 13 2019-01-14    13
# 14 2019-01-15    14
# 15 2019-01-16    15
# 16 2019-01-17    16
# 17 2019-01-18    17
# 18 2019-01-19    18
# 19 2019-01-20    19
# 20 2019-01-21    20
# 21 2019-01-22    21
# 22 2019-01-23    22
# 23 2019-01-24    23
# 24 2019-01-25    24
# 25 2019-01-26    25
# 26 2019-01-27    26
# 27 2019-01-28    27
# 28 2019-01-29    28
# 29 2019-01-30    29
# 30 2019-01-31    30
# 31 2019-02-01    31
# 32 2019-02-02    32
# 33 2019-02-03    33
# 34 2019-02-04    34
# 35 2019-02-05    35
# 36 2019-02-06    36
# 37 2019-02-07    37
# 38 2019-02-08    38
# 39 2019-02-09    39

# %%
# Create a function to scrape the data for constantly updated data from a website

def usd_gbp_new():

    url='https://www.exchangerates.org.uk/GBP-USD-spot-exchange-rates-history-2019.html'
    #Create a handle, page, to handle the contents of the website

    page = requests.get(url)#Store the contents of the website under doc

    doc = lh.fromstring(page.content)#Parse data that are stored between <tr>..</tr> of HTML

    tr_elements = doc.xpath('//tr')
    
    day = [] #Create an empty list to store the data between <tr>....</tr> tags 
    
    for t in tr_elements:
        if len(t) == 3:
            day.append(t.text_content())
            
    tmp = pd.DataFrame(day)
    tmp.columns = ['Data']
    
    tmp['Rate'] = tmp['Data'].apply(lambda x : x.split("$")[-1].split("British")[0])
    tmp['Date'] = tmp['Data'].apply(lambda x : x.split("ay")[-1].split("£1")[0])
    # filter((lambda x: re.search(r'L', x)),s)
    tmp['Date'] = pd.to_datetime(tmp['Date'])
    tmp.drop(['Data'],axis = 1,inplace = True)
    tmp.index = tmp['Date']
    
#     tmp['Rate'] = int(tmp['Rate'])
#     tmp.reindex(index=tmp.index[::-1])
    
    return(tmp)

# %%
ex_data = usd_gbp_new()

# %%
ex_data.columns
# Out:
# Index(['Rate', 'Date'], dtype='object')

# %%
ex_data.head()
# Out:
#               Rate
# Date
# 2019-01-01  1.2752
# 2019-01-02  1.2523
# 2019-01-03   1.263
# 2019-01-04  1.2729
# 2019-01-05  1.2723

# %%
ex_data['Rate'] = ex_data['Rate'] *10000

# %%
ex_data.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2019-12-07', '2019-12-08', '2019-12-09', '2019-12-10',
#                '2019-12-11', '2019-12-12', '2019-12-13', '2019-12-14',
#                '2019-12-15', '2019-12-16'],
#               dtype='datetime64[ns]', name='Date', length=350, freq=None)

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 10

# %%
plt.plot(ex_data['Rate'])
plt.title('Time Series of S&P 500') 
plt.ylabel('S&P 500 Value')
plt.xlabel('Date')
plt.grid()
plt.show()
